# %%
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, Activation
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import random

# %%
import cv2

# %%
np.random.seed(0)

# %% [markdown]
# # 1.MNIST Data load
# mnist 데이터는 28*28 사이즈를 가지며, 채널은 1개인 오픈 데이터셋입니다.

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
print ('x_train shape:',x_train.shape)
print ('x_test shape:',x_test.shape)
print ('y_train shape:',y_train.shape)
print ('y_test shape:',y_test.shape)
# Out:
# x_train shape: (60000, 28, 28)
# x_test shape: (10000, 28, 28)
# y_train shape: (60000,)
# y_test shape: (10000,)

# %%
fig = plt.figure(figsize=(10,5))
for i in range(9):
    subplot = fig.add_subplot(4, 10, i+1)
    subplot.set_xticks([])
    subplot.set_yticks([])
    subplot.set_title('%d' % (y_train[i]))
    subplot.imshow(x_train[i].reshape(28,28), vmin=0, vmax=1,
                   cmap=plt.cm.gray_r, interpolation='nearest')

# %% [markdown]
# # 2. Data preprocessing
# MNIST 데이터로 학습을 할 때에, keras 혹은 tensorflow에서는 기본으로 (N,H,W,C) 형태의 4차원 tensor를 인풋으로 학습합니다. 따라서 다운로드 받은 mnist데이터를 다음과 같은 형태로 reshape 해야하는 전처리 과정이 필요합니다.

# %%
# input image dimensions
img_rows, img_cols = 28, 28
num_classes =10

# %%
x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
input_shape = (img_rows, img_cols, 1)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %% [markdown]
# 아웃풋은 one-hot encoding 방식으로 표현된 벡터로 표현합니다. MNIST의 총 클래수 갯수는 10개이므로 (N,10)의 형태로 reshape하는 전처리 과정이 필요합니다.

# %%
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
print ('x_train shape:',x_train.shape)
print ('x_test shape:',x_test.shape)
print ('y_train shape:',y_train.shape)
print ('y_test shape:',y_test.shape)
# Out:
# x_train shape: (60000, 28, 28, 1)
# x_test shape: (10000, 28, 28, 1)
# y_train shape: (60000, 10)
# y_test shape: (10000, 10)

# %% [markdown]
# # 실습1. Padding 과 Stride
# padding과 stride를 바꿔가며 아웃풋의 형태가 어떻게 변하는지 알아보는 실습입니다.
# 1. padding :
# padding="same" 은 padding을 사용하여 인풋과 아웃풋 형태가 동일하게 한다는 의미입니다. 반대로 padding="valid"는 padding 을 사용하지 않는다는 의미입니다.
#
# 2. stride :
# stride는 (가로이동수, 세로이동수) 로 표현합니다. 주로 (1,1), (2,2) 와 같이 가로,세로 동일하게 이동합니다.

# %% [markdown]
# 커널을 정의할 때는,
# 1. 커널의 갯수
# 2. 커널의 사이즈
# 3. 스트라이드
# 4. 패딩 여부
# 가 필요합니다.

# %%
model = Sequential()
model.add(Conv2D(filters = 2, 
                kernel_size=(3,3),
                strides = (1,1),
                padding='same',
                input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2,2)))
# Out:
# WARNING:tensorflow:From C:\Users\gin908\AppData\Local\conda\conda\envs\kaist_cnn_3.6\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# 생성된 모델은 **summary()** 함수를 통해 그 구조를 출력할 수 있습니다.

# %%
print (input_shape)
print( model.summary())
# Out:
# (28, 28, 1)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 28, 28, 2)         20
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 2)         0
# =================================================================
# Total params: 20
# Trainable params: 20
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model = Sequential()
model.add(Conv2D(filters = 2, 
                kernel_size=(3,3),
                strides = (3,3),
                padding='same',
                input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2,2)))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 10, 10, 2)         20
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 2)           0
# =================================================================
# Total params: 20
# Trainable params: 20
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = Sequential()
model.add(Conv2D(filters = 2, 
                kernel_size=(3,3),
                strides = (1,1),
                padding='valid',
                input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2,2)))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 26, 26, 2)         20
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 13, 13, 2)         0
# =================================================================
# Total params: 20
# Trainable params: 20
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Now, Guess how output looks like!

# %%
model = Sequential()
model.add(Conv2D(filters = 3, 
                kernel_size=(5,5),
                strides = (1,1),
                padding='same',
                input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2,2)))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 28, 28, 3)         78
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 14, 14, 3)         0
# =================================================================
# Total params: 78
# Trainable params: 78
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 2 .convolution filter의 역할
# CNN에서의 filter 혹은 kernel은 이미지의 특징을 추출하기 위한 공용 파라미터를 의미합니다. 따라서 이 filter를 학습함에 따라 목표에 맞는(예를 들어, 1~10 까지 classifcation) kernel weight들을 학습하는 것이 CNN의 feature extraction 과정에서 하는 것입니다.
# 그렇다면 filter가 어떻게 특징을 추출할 수 있는 것일까요?
# filter에 수업 때 배운 여러 weight들을 집어넣으면서 이미지에서 어떤 feature가 추출되는지실습을 통해 알아보겠습니다.

# %% [markdown]
# 아래 함수는, 사용한 filter와 그 filter를 통해 나온 output을 plot하는 함수입니다.

# %%
def plot_cnn(filter_vals, applied_vals):
    fig = plt.figure(figsize=(10,3))

    for i in range(2):
        subplot = fig.add_subplot(3, 10, 10*(i+1)+1)
        subplot.set_xticks([])
        subplot.set_yticks([])
        subplot.imshow(filter_vals[:,:,0,i],
                       cmap=plt.cm.gray_r, interpolation='nearest')

    v_max = np.max(applied_vals)

    for i in range(9):
        subplot = fig.add_subplot(3, 10, i+2)
        subplot.set_xticks([])
        subplot.set_yticks([])
        subplot.set_title('%d' % np.argmax(y_train[i]))
        subplot.imshow(x_train[:9].T[0].T[i].reshape((28,28)), vmin=0, vmax=1,
                       cmap=plt.cm.gray_r, interpolation='nearest')

        subplot = fig.add_subplot(3, 10, 10+i+2)
        subplot.set_xticks([])
        subplot.set_yticks([])
        subplot.imshow(applied_vals[i,:,:,0], vmin=0, vmax=v_max,
                       cmap=plt.cm.gray_r, interpolation='nearest')

        subplot = fig.add_subplot(3, 10, 20+i+2)
        subplot.set_xticks([])
        subplot.set_yticks([])
        subplot.imshow(applied_vals[i,:,:,1], vmin=0, vmax=v_max,
                       cmap=plt.cm.gray_r, interpolation='nearest')

# %% [markdown]
# 먼저, CNN에서 feature extraction 부분을 구성하는, convolution layer와 pooling layer 를 가지는 모델을 만들어보겠습니다.

# %%
model = Sequential()
model.add(Conv2D(filters = 2, 
                kernel_size=(3,3),
                strides = (1,1),
                padding='same',
                use_bias =False,
                input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2,2)))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 28, 28, 2)         18
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 14, 14, 2)         0
# =================================================================
# Total params: 18
# Trainable params: 18
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 모델의 구조는 정해졌으니, 이 정해진 구조에 특정한 input을 넣으면 convolution layer와 pooling layer의 output을 리턴해주는 간단한 함수입니다.

# %%
conv_output_func = K.function([model.input], [model.layers[0].output])
pool_output_func = K.function([model.input], [model.layers[1].output])

# %% [markdown]
# ### (1)with initialized(randomed) weights
# 모델의 구조를 정하고, 커널이 initialize 되었을 때, 트레이닝 데이터 9개를 넣으면 어떤 모습일지 확인해봅니다.

# %%
conv_output = np.asarray(conv_output_func([x_train[0:9]]))[0]
print (conv_output.shape)
# Out:
# (9, 28, 28, 2)

# %%
conv_weights = np.asarray(model.layers[0].get_weights())[0]

# %%
pool_output = np.asarray(pool_output_func([x_train[0:9]]))[0]

# %% [markdown]
# filter(convolution)을 거치고 난 후의 output은 어떤 모습일까?

# %%
plot_cnn(conv_weights,conv_output)

# %% [markdown]
# pooling을 거치고 난 후의 output은 어떤 모습일까?

# %%
plot_cnn(conv_weights,pool_output)

# %% [markdown]
# ### <font color=red> (2) TRY! create own weights and see what happens!</font>

# %% [markdown]
# **Kernel for detecting several patterns**
# 아래있는 여러 kernel들을 참고하여 2가지의 filter을 고른 후, 모델에 해당filter를 적용해주세요
# 예시)
#
# <img src="./img/convolutional_kernel.PNG" alt="convolutional_kernel" title="convolutional_kernel" />

# %% [raw]
# #예시
# blur_filter = np.array(
#     [[0.0625,0.125,0.0625],
#      [0.125,0.25,0.125],
#      [0.0625,0.125,0.0625]])
# edge_filter = np.array(
# [[1,0,-1],
#  [2,0,-2],
#  [1,0,-1]])

# %%
blur_filter = np.array(
    [[0.0625,0.125,0.0625],
     [0.125,0.25,0.125],
     [0.0625,0.125,0.0625]]) 
edge_filter = np.array(
[[-1,-1,-1],
 [-1,8,-1],
 [-1,-1,-1]]) 

filter_array = np.zeros([3,3,1,2])
filter_array[:,:,0,0] = blur_filter
filter_array[:,:,0,1] = edge_filter

# %%
model.layers[0].set_weights(filter_array.reshape(1,3,3,1,2))

# %%
conv_output = np.asarray(conv_output_func([x_train[0:9]]))[0]
print (conv_output.shape)
# Out:
# (9, 28, 28, 2)

# %%
conv_weights = np.asarray(model.layers[0].get_weights())[0]

# %%
pool_output = np.asarray(pool_output_func([x_train[0:9]]))[0]

# %%
plot_cnn(conv_weights,conv_output)

# %%
plot_cnn(conv_weights,pool_output)

# %% [markdown]
# 위의 실험에서 보았듯이, 어떠한 kernel을 사용하냐에 따라 추출되는 feature가 다릅니다. 이 feature들은 마지막에 클래지피게이션하는 input으로 사용되므로 목적에 맞는 feature를 잘 추출하는 것이 필요합니다. 따라서 CNN에서는 이 kernel를 학습합니다.

# %% [markdown]
# # 2. MLP vs CNN
# 지금까지 CNN의 feature extractor 부분에 집중하여 1. convolution layer의 필터갯수, 필터크기, 스트라이드, 패딩여부에 따라 output 형태가 달라지고,
# 2. kernel 에 따라 다양한 feature가 추출되므로, 이 kernel를 학습하는 것이 중요하다는 것을 알게되었습니다.
#
# 다음으로는 MLP와 CNN를 각각 학습하면서, MLP와 CNN를 비교해보겠습니다.

# %% [markdown]
# <img src="./img/mlp_structure.png" alt="mlp_structure" title="mlp_structure" />

# %%
def plot_prediction(model, input_data, correctness):
    predicted_result = model.predict(input_data)
    predicted_labels = np.argmax(predicted_result, axis=1)

    test_labels = np.argmax(y_test, axis=1)
    result = []
    if correctness ==False:
        for n in range(0, len(test_labels)):
            if predicted_labels[n] != test_labels[n]:
                result.append(n)
        title = "wrong"
    elif correctness ==True:
        for n in range(0, len(test_labels)):
            if predicted_labels[n] == test_labels[n]:
                result.append(n)
        title="correct"
    
    samples = random.choices(population=result, k=16)

    count = 0
    nrows = ncols = 4

    plt.figure(figsize=(12,8))

    for n in samples:
        count += 1
        plt.subplot(nrows, ncols, count)
        if correctness ==False:
            plt.imshow(x_test[n].reshape(28, 28), cmap='Reds', interpolation='nearest')
        elif correctness ==True:
            plt.imshow(x_test[n].reshape(28, 28), cmap='Blues', interpolation='nearest')
        tmp = "Label:" + str(test_labels[n]) + ", Prediction:" + str(predicted_labels[n])
        plt.title(tmp)

    plt.tight_layout()
    plt.suptitle(str(title)+' prediction', fontsize=15)
    plt.subplots_adjust(top=0.85)
    plt.show()
    
    return samples

# %%
import os

# %%
batch_size= 128

# %% [markdown]
# ## (1) Building MLP model

# %%
from keras.callbacks import ModelCheckpoint

# %%
MODEL_SAVE_FOLDER_PATH = './model/'
if not os.path.exists(MODEL_SAVE_FOLDER_PATH):
    os.mkdir(MODEL_SAVE_FOLDER_PATH)

mlp_model_path = MODEL_SAVE_FOLDER_PATH + 'mlp_model.hdf5'

# %%
def mlp_model_build(input_shape, num_classes):
    model = Sequential()
    
    model.add(Dense(300, input_shape = input_shape, kernel_initializer='he_normal'))     # use he_normal initializer
    model.add(Activation('relu'))    
    model.add(Dense(100, kernel_initializer='he_normal'))                            # use he_normal initializer
    model.add(Activation('relu'))    
    model.add(Dense(50, kernel_initializer='he_normal'))                            # use he_normal initializer
    model.add(Activation('relu'))    
    model.add(Dense(10, kernel_initializer='he_normal'))                            # use he_normal initializer
    model.add(Activation('softmax'))

    model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
    
    cb_checkpoint = ModelCheckpoint(filepath=mlp_model_path, monitor='val_loss',
                                verbose=1, save_best_only=True)

    return model,cb_checkpoint

# %%
mlp_model,cb_checkpoint = mlp_model_build(input_shape= (28*28,), num_classes=num_classes)
mlp_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 300)               235500
# _________________________________________________________________
# activation_1 (Activation)    (None, 300)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               30100
# _________________________________________________________________
# activation_2 (Activation)    (None, 100)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 50)                5050
# _________________________________________________________________
# activation_3 (Activation)    (None, 50)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                510
# _________________________________________________________________
# activation_4 (Activation)    (None, 10)                0
# =================================================================
# Total params: 271,160
# Trainable params: 271,160
# Non-trainable params: 0
# _________________________________________________________________

# %%
mlp_history = mlp_model.fit(x_train.reshape(60000,28*28), 
                            y_train, 
                            validation_split = 0.3,
                            callbacks=[cb_checkpoint],
                            batch_size=batch_size,
                            epochs = 20, 
                            verbose = 1)
# Out:
# WARNING:tensorflow:From C:\Users\gin908\AppData\Local\conda\conda\envs\kaist_cnn_3.6\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 42000 samples, validate on 18000 samples
# Epoch 1/20
# 42000/42000 [==============================] - 3s 81us/step - loss: 0.3108 - acc: 0.9052 - val_loss: 0.1962 - val_acc: 0.9407
#
# Epoch 00001: val_loss improved from inf to 0.19616, saving model to ./model/mlp_model.hdf5
# Epoch 2/20
# 42000/42000 [==============================] - 2s 57us/step - loss: 0.1206 - acc: 0.9634 - val_loss: 0.1675 - val_acc: 0.9489
#
# Epoch 00002: val_loss improved from 0.19616 to 0.16749, saving model to ./model/mlp_model.hdf5
# Epoch 3/20
# 42000/42000 [==============================] - 2s 57us/step - loss: 0.0792 - acc: 0.9754 - val_loss: 0.1160 - val_acc: 0.9676
#
# Epoch 00003: val_loss improved from 0.16749 to 0.11605, saving model to ./model/mlp_model.hdf5
# Epoch 4/20
# 42000/42000 [==============================] - 2s 57us/step - loss: 0.0563 - acc: 0.9828 - val_loss: 0.1037 - val_acc: 0.9716
#
# Epoch 00004: val_loss improved from 0.11605 to 0.10367, saving model to ./model/mlp_model.hdf5
# Epoch 5/20
# 42000/42000 [==============================] - 3s 63us/step - loss: 0.0417 - acc: 0.9867 - val_loss: 0.1090 - val_acc: 0.9696
#
# Epoch 00005: val_loss did not improve from 0.10367
# Epoch 6/20
# 42000/42000 [==============================] - 3s 61us/step - loss: 0.0308 - acc: 0.9897 - val_loss: 0.1280 - val_acc: 0.9679
#
# Epoch 00006: val_loss did not improve from 0.10367
# Epoch 7/20
# 42000/42000 [==============================] - 3s 64us/step - loss: 0.0249 - acc: 0.9922 - val_loss: 0.1937 - val_acc: 0.9513
#
# Epoch 00007: val_loss did not improve from 0.10367
# Epoch 8/20
# 42000/42000 [==============================] - 3s 70us/step - loss: 0.0199 - acc: 0.9937 - val_loss: 0.1062 - val_acc: 0.9746
#
# Epoch 00008: val_loss did not improve from 0.10367
# Epoch 9/20
# 42000/42000 [==============================] - 3s 71us/step - loss: 0.0143 - acc: 0.9953 - val_loss: 0.1347 - val_acc: 0.9732
#
# Epoch 00009: val_loss did not improve from 0.10367
# Epoch 10/20
# 42000/42000 [==============================] - 3s 66us/step - loss: 0.0138 - acc: 0.9956 - val_loss: 0.1248 - val_acc: 0.9753
#
# Epoch 00010: val_loss did not improve from 0.10367
# Epoch 11/20
# 42000/42000 [==============================] - 3s 61us/step - loss: 0.0104 - acc: 0.9965 - val_loss: 0.1471 - val_acc: 0.9709
#
# Epoch 00011: val_loss did not improve from 0.10367
# Epoch 12/20
# 42000/42000 [==============================] - 3s 60us/step - loss: 0.0100 - acc: 0.9966 - val_loss: 0.1355 - val_acc: 0.9742
#
# Epoch 00012: val_loss did not improve from 0.10367
# Epoch 13/20
# 42000/42000 [==============================] - 3s 64us/step - loss: 0.0070 - acc: 0.9977 - val_loss: 0.1399 - val_acc: 0.9744
#
# Epoch 00013: val_loss did not improve from 0.10367
# Epoch 14/20
# 42000/42000 [==============================] - 3s 69us/step - loss: 0.0067 - acc: 0.9980 - val_loss: 0.1381 - val_acc: 0.9758
#
# Epoch 00014: val_loss did not improve from 0.10367
# Epoch 15/20
# 42000/42000 [==============================] - 3s 69us/step - loss: 0.0066 - acc: 0.9979 - val_loss: 0.1529 - val_acc: 0.9739
#
# Epoch 00015: val_loss did not improve from 0.10367
# Epoch 16/20
# 42000/42000 [==============================] - 3s 60us/step - loss: 0.0057 - acc: 0.9980 - val_loss: 0.1504 - val_acc: 0.9764
#
# Epoch 00016: val_loss did not improve from 0.10367
# Epoch 17/20
# 42000/42000 [==============================] - 3s 69us/step - loss: 0.0058 - acc: 0.9981 - val_loss: 0.1616 - val_acc: 0.9742
#
# Epoch 00017: val_loss did not improve from 0.10367
# Epoch 18/20
# 42000/42000 [==============================] - 3s 63us/step - loss: 0.0055 - acc: 0.9982 - val_loss: 0.1656 - val_acc: 0.9761
#
# Epoch 00018: val_loss did not improve from 0.10367
# Epoch 19/20
# 42000/42000 [==============================] - 3s 64us/step - loss: 0.0057 - acc: 0.9985 - val_loss: 0.1527 - val_acc: 0.9778
#
# Epoch 00019: val_loss did not improve from 0.10367
# Epoch 20/20
# 42000/42000 [==============================] - 3s 66us/step - loss: 0.0034 - acc: 0.9988 - val_loss: 0.1490 - val_acc: 0.9781
#
# Epoch 00020: val_loss did not improve from 0.10367

# %%
mlp_vloss= mlp_history.history['val_loss']
mlp_loss = mlp_history.history['loss']

x_len = np.arange(len(mlp_loss))
plt.plot(x_len, mlp_vloss, marker='.', c='red', label="Validation-set Loss")
plt.plot(x_len, mlp_loss, marker='.', c='blue', label="Train-set Loss")

plt.legend(loc='upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.ylim(0,1)
plt.show()

# %%
mlp_model.load_weights(mlp_model_path)

# %%
wrong_samples_idx = plot_prediction(model =mlp_model, input_data = x_test.reshape(10000,28*28,),correctness =False)

# %%
correct_samples_idx = plot_prediction(model =mlp_model, input_data = x_test.reshape(10000,28*28,),correctness =True)

# %% [markdown]
# ## data를 translation 했을때

# %% [markdown]
# <img src="./img/image_translation.jpg" alt="image_translation" title="image_translation" />

# %%
translation_matrix = np.float32([ [1,0,0], [0,1,-3] ])
x_test_translation=np.asarray([cv2.warpAffine(x, translation_matrix, (28, 28)) for x in x_test[correct_samples_idx]])

# %%
predicted_result = mlp_model.predict(x_test_translation.reshape(16,28*28))
predicted_labels = np.argmax(predicted_result, axis=1)

test_labels = np.argmax(y_test[correct_samples_idx], axis=1)
result = []


count = 0
nrows = ncols = 4

plt.figure(figsize=(12,8))

for n in range(0,16):
    count += 1
    #if test_labels[n]!=predicted_labels[n]:
    plt.subplot(nrows, ncols, count)
    if test_labels[n]!=predicted_labels[n]:
        plt.imshow(x_test_translation[n].reshape(28, 28), cmap='Reds', interpolation='nearest')
    else : 
        plt.imshow(x_test_translation[n].reshape(28, 28), cmap='Blues', interpolation='nearest')
    
    tmp = "Label:" + str(test_labels[n]) + ", Prediction:" + str(predicted_labels[n])
    plt.title(tmp)

plt.tight_layout()
plt.suptitle('translated image prediction', fontsize=15)
plt.subplots_adjust(top=0.85)
plt.show()

# %% [markdown]
# <img src="./img/image_rotation1.png" alt="image_rotation1" title="image_rotation1" />
# <img src="./img/image_rotation2.png" alt="image_rotation2" title="image_rotation2" />

# %%
rotation_matrix= cv2.getRotationMatrix2D((28/2, 28/2), 10, 1.0)
x_test_rotation=np.asarray([cv2.warpAffine(x, rotation_matrix, (28, 28)) for x in x_test[correct_samples_idx]])

# %%
predicted_result = mlp_model.predict(x_test_rotation.reshape(16,28*28))
predicted_labels = np.argmax(predicted_result, axis=1)

test_labels = np.argmax(y_test[correct_samples_idx], axis=1)
result = []


count = 0
nrows = ncols = 4

plt.figure(figsize=(12,8))

for n in range(0,16):
    count += 1
    #if test_labels[n]!=predicted_labels[n]:
    plt.subplot(nrows, ncols, count)
    if test_labels[n]!=predicted_labels[n]:
        plt.imshow(x_test_rotation[n].reshape(28, 28), cmap='Reds', interpolation='nearest')
    else : 
        plt.imshow(x_test_rotation[n].reshape(28, 28), cmap='Blues', interpolation='nearest')
    
    tmp = "Label:" + str(test_labels[n]) + ", Prediction:" + str(predicted_labels[n])
    plt.title(tmp)

plt.tight_layout()
plt.suptitle('rotated image prediction', fontsize=15)
plt.subplots_adjust(top=0.85)
plt.show()

# %% [markdown]
# ## (2) Build CNN model

# %%
MODEL_SAVE_FOLDER_PATH = './model/'
if not os.path.exists(MODEL_SAVE_FOLDER_PATH):
    os.mkdir(MODEL_SAVE_FOLDER_PATH)

cnn_model_path = MODEL_SAVE_FOLDER_PATH + 'cnn_model.hdf5'

# %% [markdown]
# CNN은 MLP와는 달리 이미지를 그대로 받아 오기 때문에,
# 인풋은 [batch, 이미지높이, 이미지너비, 이미지채널]의 모양을 가지는 4차원 텐서이며,
# Y는 분류의 사용될 라벨 값을 받아오는 [batch]의 모양의 1차원 텐서입니다.

# %%
def cnn_model_build(input_shape, num_classes):
        model = Sequential()
        # CONV => RELU => POOL
        model.add(Conv2D(2, kernel_size=(3,3), padding="same",input_shape=input_shape))
        model.add(Activation("relu"))
        model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
        
        # CONV => RELU => POOL
        model.add(Conv2D(10, kernel_size=(5,5), padding="same"))
        model.add(Activation("relu"))
        model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
        
        # CONV => RELU => POOL
        model.add(Conv2D(50, kernel_size=(7,7), padding="same"))
        model.add(Activation("relu"))
        model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
        
        # Flatten => RELU layers
        model.add(Flatten())
        model.add(Dense(50))
        model.add(Activation("relu"))
 
        # a softmax classifier
        model.add(Dense(num_classes))
        model.add(Activation("softmax"))
        cb_checkpoint = ModelCheckpoint(filepath=cnn_model_path, monitor='val_loss',
                                verbose=1, save_best_only=True)
        model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
        return model,cb_checkpoint

# %%
cnn_model,cb_checkpoint = cnn_model_build(input_shape = (28,28,1), num_classes=num_classes)
cnn_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 28, 28, 2)         20
# _________________________________________________________________
# activation_5 (Activation)    (None, 28, 28, 2)         0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 14, 14, 2)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 14, 14, 10)        510
# _________________________________________________________________
# activation_6 (Activation)    (None, 14, 14, 10)        0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 7, 7, 10)          0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 7, 7, 50)          24550
# _________________________________________________________________
# activation_7 (Activation)    (None, 7, 7, 50)          0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 3, 3, 50)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 450)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 50)                22550
# _________________________________________________________________
# activation_8 (Activation)    (None, 50)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                510
# _________________________________________________________________
# activation_9 (Activation)    (None, 10)                0
# =================================================================
# Total params: 48,140
# Trainable params: 48,140
# Non-trainable params: 0
# _________________________________________________________________

# %%
cnn_history = cnn_model.fit(x_train, 
                            y_train, 
                            validation_split = 0.3, 
                            callbacks=[cb_checkpoint],
                            batch_size=batch_size,
                            epochs = 20, 
                            verbose = 1)
# Out:
# Train on 42000 samples, validate on 18000 samples
# Epoch 1/20
# 42000/42000 [==============================] - 47s 1ms/step - loss: 0.4459 - acc: 0.8649 - val_loss: 0.4811 - val_acc: 0.8544
#
# Epoch 00001: val_loss improved from inf to 0.48111, saving model to ./model/cnn_model.hdf5
# Epoch 2/20
# 42000/42000 [==============================] - 46s 1ms/step - loss: 0.1257 - acc: 0.9609 - val_loss: 0.1126 - val_acc: 0.9629
#
# Epoch 00002: val_loss improved from 0.48111 to 0.11262, saving model to ./model/cnn_model.hdf5
# Epoch 3/20
# 42000/42000 [==============================] - 48s 1ms/step - loss: 0.0817 - acc: 0.9736 - val_loss: 0.0891 - val_acc: 0.9729
#
# Epoch 00003: val_loss improved from 0.11262 to 0.08914, saving model to ./model/cnn_model.hdf5
# Epoch 4/20
# 42000/42000 [==============================] - 47s 1ms/step - loss: 0.0624 - acc: 0.9806 - val_loss: 0.0721 - val_acc: 0.9770
#
# Epoch 00004: val_loss improved from 0.08914 to 0.07209, saving model to ./model/cnn_model.hdf5
# Epoch 5/20
# 42000/42000 [==============================] - 48s 1ms/step - loss: 0.0492 - acc: 0.9843 - val_loss: 0.0767 - val_acc: 0.9776
#
# Epoch 00005: val_loss did not improve from 0.07209
# Epoch 6/20
# 42000/42000 [==============================] - 49s 1ms/step - loss: 0.0395 - acc: 0.9870 - val_loss: 0.0836 - val_acc: 0.9759
#
# Epoch 00006: val_loss did not improve from 0.07209
# Epoch 7/20
# 42000/42000 [==============================] - 48s 1ms/step - loss: 0.0333 - acc: 0.9895 - val_loss: 0.0582 - val_acc: 0.9825
#
# Epoch 00007: val_loss improved from 0.07209 to 0.05821, saving model to ./model/cnn_model.hdf5
# Epoch 8/20
# 42000/42000 [==============================] - 47s 1ms/step - loss: 0.0275 - acc: 0.9911 - val_loss: 0.0643 - val_acc: 0.9816
#
# Epoch 00008: val_loss did not improve from 0.05821
# Epoch 9/20
# 42000/42000 [==============================] - 49s 1ms/step - loss: 0.0237 - acc: 0.9918 - val_loss: 0.0968 - val_acc: 0.9738
#
# Epoch 00009: val_loss did not improve from 0.05821
# Epoch 10/20
# 42000/42000 [==============================] - 47s 1ms/step - loss: 0.0197 - acc: 0.9935 - val_loss: 0.0615 - val_acc: 0.9828
#
# Epoch 00010: val_loss did not improve from 0.05821
# Epoch 11/20
# 42000/42000 [==============================] - 48s 1ms/step - loss: 0.0170 - acc: 0.9943 - val_loss: 0.0914 - val_acc: 0.9778
#
# Epoch 00011: val_loss did not improve from 0.05821
# Epoch 12/20
# 42000/42000 [==============================] - 47s 1ms/step - loss: 0.0157 - acc: 0.9952 - val_loss: 0.0748 - val_acc: 0.9816
#
# Epoch 00012: val_loss did not improve from 0.05821
# Epoch 13/20
# 42000/42000 [==============================] - 47s 1ms/step - loss: 0.0135 - acc: 0.9953 - val_loss: 0.0706 - val_acc: 0.9826
#
# Epoch 00013: val_loss did not improve from 0.05821
# Epoch 14/20
# 42000/42000 [==============================] - 46s 1ms/step - loss: 0.0121 - acc: 0.9962 - val_loss: 0.0679 - val_acc: 0.9837
#
# Epoch 00014: val_loss did not improve from 0.05821
# Epoch 15/20
# 42000/42000 [==============================] - 46s 1ms/step - loss: 0.0097 - acc: 0.9966 - val_loss: 0.0788 - val_acc: 0.9817
#
# Epoch 00015: val_loss did not improve from 0.05821
# Epoch 16/20
# 42000/42000 [==============================] - 46s 1ms/step - loss: 0.0095 - acc: 0.9969 - val_loss: 0.0829 - val_acc: 0.9810
#
# Epoch 00016: val_loss did not improve from 0.05821
# Epoch 17/20
# 42000/42000 [==============================] - 46s 1ms/step - loss: 0.0082 - acc: 0.9973 - val_loss: 0.0969 - val_acc: 0.9807
#
# Epoch 00017: val_loss did not improve from 0.05821
# Epoch 18/20
# 42000/42000 [==============================] - 47s 1ms/step - loss: 0.0073 - acc: 0.9975 - val_loss: 0.0779 - val_acc: 0.9847
#
# Epoch 00018: val_loss did not improve from 0.05821
# Epoch 19/20
# 42000/42000 [==============================] - 47s 1ms/step - loss: 0.0072 - acc: 0.9978 - val_loss: 0.0773 - val_acc: 0.9847
#
# Epoch 00019: val_loss did not improve from 0.05821
# Epoch 20/20
# 42000/42000 [==============================] - 46s 1ms/step - loss: 0.0069 - acc: 0.9979 - val_loss: 0.0801 - val_acc: 0.9833
#
# Epoch 00020: val_loss did not improve from 0.05821
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-ccf5b1e1d901> in <module>
#       6                             epochs = 20,
#       7                             verbose = 1)
# ----> 8 print('Test loss:', score[0])
#       9 print('Test accuracy:', score[1])
#
# NameError: name 'score' is not defined

# %%
cnn_vloss= cnn_history.history['val_loss']
cnn_loss = cnn_history.history['loss']

x_len = np.arange(len(cnn_loss))
plt.plot(x_len, cnn_vloss, marker='.', c='red', label="Validation-set Loss")
plt.plot(x_len, cnn_loss, marker='.', c='blue', label="Train-set Loss")

plt.legend(loc='upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.ylim(0,1)
plt.show()

# %%
cnn_model.load_weights(cnn_model_path)

# %%
wrong_samples_idx = plot_prediction(model =cnn_model, input_data = x_test.reshape(10000,28,28,1),correctness =False)

# %%
correct_samples_idx = plot_prediction(model =cnn_model, input_data = x_test.reshape(10000,28,28,1),correctness =True)

# %%
x_test_translation=np.asarray([cv2.warpAffine(x, translation_matrix, (28, 28)) for x in x_test[correct_samples_idx]])

# %%
predicted_result = cnn_model.predict(x_test_translation.reshape(16,28,28,1))
predicted_labels = np.argmax(predicted_result, axis=1)

test_labels = np.argmax(y_test[correct_samples_idx], axis=1)
result = []


count = 0
nrows = ncols = 4

plt.figure(figsize=(12,8))

for n in range(0,16):
    count += 1
    plt.subplot(nrows, ncols, count)
    if test_labels[n]!=predicted_labels[n]:
        plt.imshow(x_test_translation[n].reshape(28, 28), cmap='Reds', interpolation='nearest')
    else : 
        plt.imshow(x_test_translation[n].reshape(28, 28), cmap='Blues', interpolation='nearest')
    tmp = "Label:" + str(test_labels[n]) + ", Prediction:" + str(predicted_labels[n])
    plt.title(tmp)

plt.tight_layout()
plt.suptitle('translated image prediction', fontsize=15)
plt.subplots_adjust(top=0.85)
plt.show()

# %%
x_test_rotation=np.asarray([cv2.warpAffine(x, rotation_matrix, (28, 28)) for x in x_test[correct_samples_idx]])

# %%
predicted_result = cnn_model.predict(x_test_rotation.reshape(16,28,28,1))
predicted_labels = np.argmax(predicted_result, axis=1)

test_labels = np.argmax(y_test[correct_samples_idx], axis=1)
result = []


count = 0
nrows = ncols = 4

plt.figure(figsize=(12,8))

for n in range(0,16):
    count += 1
    plt.subplot(nrows, ncols, count)
    if test_labels[n]!=predicted_labels[n]:
        plt.imshow(x_test_rotation[n].reshape(28, 28), cmap='Reds', interpolation='nearest')
    else : 
        plt.imshow(x_test_rotation[n].reshape(28, 28), cmap='Blues', interpolation='nearest')
    tmp = "Label:" + str(test_labels[n]) + ", Prediction:" + str(predicted_labels[n])
    plt.title(tmp)

plt.tight_layout()
plt.suptitle('rotated image prediction', fontsize=15)
plt.subplots_adjust(top=0.85)
plt.show()
